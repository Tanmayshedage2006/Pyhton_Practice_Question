# %%
data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]
data[2][1][2] # indexing of inside a nested list
# Out:
# 'target'

# %%
#  Append
colors = ["red", "blue"]
colors.append(["green", "yellow"])
colors
# Out:
# ['red', 'blue', ['green', 'yellow']]

# %%
# Extend
colors = ["red", "blue"]
colors.extend(["green", "yellow"])
colors # it removs list square bra ket it print
# Out:
# ['red', 'blue', 'green', 'yellow']

# %%
# Matrix 
matrix=[[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix[1][2]
# Out:
# 6

# %%
# insert 
nums = [10, 20, 40]
nums.insert(2, 30)
nums
# Out:
# [10, 20, 30, 40]

# %%
mixed = [1, "Python", [True, False]]
mixed[2][1]= None
mixed # Using indexing we change the number
# Out:
# [1, 'Python', [True, None]]

# %%
nested = [1, [2, 3, [4, 5, 6]], 7]
nested[1][0]
nested[1][2]
nested[1][2][1] # for accesing the number from nested list
# Out:
# 5

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]
matrix[1]
# Out:
# [40, 50, 60]

# %%
matrix[2][2]
# Out:
# 90

# %%
matrix[1][0]
# Out:
# 40

# %%
# append
fruits = ['apple', 'banana']
fruits.append(['kiwi', 'mango'])

# %%
fruits
# Out:
# ['apple', 'banana', ['kiwi', 'mango']]

# %%
fruits.extend(['kiwi', 'mango'])
fruits
# Out:
# ['apple', 'banana', ['kiwi', 'mango'], 'kiwi', 'mango', 'kiwi', 'mango']

# %%
nums = [10, 20, 40, 50]
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40, 50]

# %%
# Advanced question
l = [5, 6, [7, 8, 9], 10]
l[2][1]
# Out:
# 8

# %%
data = [1, 2]
data.extend([3, [4, 5]])

# %%
data # inner list remain a single
# Out:
# [1, 2, 3, [4, 5]]

# %%
 x = [10, [20, 'hello']]
 x[1][1]='hi'

# %%
x
# Out:
# [10, [20, 'hi']]

# %%
 vals = [1, 2, 3]
 vals.insert(0, [0])

# %%
vals #
# Out:
# [[0], 1, 2, 3]
