# %% [raw]
# 1:- would you convert one data type to another in Python? For example, an integer to a
# string.

# %%
num=4
a=str(num)

# %%
num='4'

# %%
type(num)
# Out:
# str

# %% [raw]
# 2 :- What is the difference between == and = in Python?

# %%
a=5 # = is used to the assign a value
a==5 # == is equal to is a comparison operator
# Out:
# True

# %% [raw]
#  3:- How does the modulus operator (%) work in Python?

# %%
10%2 # in simple moduls give us the remainder
10%3
# Out:
# 1

# %% [raw]
# 4:- What will be the output of 3 * "Hello" in Python? Explain why

# %%
3 *'Hello' #, multiplying a string by an integer repeats the string that many times
# Out:
# 'HelloHelloHello'

# %% [raw]
# 5 :- What is string concatenation, and how would you do it in Python?

# %%
First_name="Tanmay"
Last_name="Shedage"
First_name+" " +Last_name +"
# Out:
#   Cell In[24], line 3
#     First_name+" " +Last_name +"
#                                ^
# SyntaxError: unterminated string literal (detected at line 3)
