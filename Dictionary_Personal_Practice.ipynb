# %%
a={
    "ID":"123",
    "color":"green",
    "year":"2026"
}
print(a)  # Creating  dictionary where keys and values are stored
# Out:
# {'ID': '123', 'color': 'green', 'year': '2026'}

# %%
a={
    "ID":"123",
    "color":"green",
    "year":"2026"
}
print(a)
print(len(a))
                   # length of dictionary
# Out:
# {'ID': '123', 'color': 'green', 'year': '2026'}
# 3

# %%
a['age']='28'
print(a)    # Change in a dictionary
# Out:
# {'ID': '123', 'color': 'green', 'year': '2026', 'age': '28'}

# %%
a.pop("age")
# Out:
# '28'

# %%
print(a) # pop the last key and element
# Out:
# {'ID': '123', 'color': 'green', 'year': '2026'}

# %%
del a["year"]

# %%
print(a) # delete the specific a key and element
# Out:
# {'ID': '123', 'color': 'green'}

# %%
a.clear() # clear the all dictionary

# %%
print(a)
# Out:
# {}

# %%
dict1={1:10,2:20}
dict2={3:30,4:40}
dict3={5:50,6:60}
dict4={}
for d in in (dict1,dict2,dict3,)
