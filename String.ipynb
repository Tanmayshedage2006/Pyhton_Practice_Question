# %%
a="hello"
print(a[1])    # Indexing
# Out:
# e

# %%
s="Hello how are you?"
print(s[0:5])  # Slicing of strings
# Out:
# Hello

# %%
s="Hello student"
print(s[::-1])  # Reverse a list
# Out:
# tneduts olleH

# %%
print(len(a)) # length of string
# Out:
# 5

# %%
b="Hello how are you?"
print(b.upper()) # Convert the all string into a upper method
# Out:
# HELLO HOW ARE YOU?

# %%
print(b.lower()) # convert the all string into a lower method
# Out:
# hello how are you?

# %%
c="Hello how are you ?"
print(c.replace("Hello","Hi"))
# Out:
# Hi how are you ?
