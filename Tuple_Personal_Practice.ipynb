# %%
my_tuple=(1,2,3)
print(my_tuple)       # Creating a Tuple
# Out:
# (1, 2, 3)

# %%
my_tuple=(1,"hello","2.3",4+5j)

# %%
print(my_tuple)      # Tuple can have mixed data type
# Out:
# (1, 'hello', '2.3', (4+5j))

# %%
a=(2,3,4,"hello",("ok"))
print(a)              # Nested tuple
# Out:
# (2, 3, 4, 'hello', 'ok')

# %%
a=tuple(("a","b","c"))
print(a)
print(type(a))  #Tuple constructor
# Out:
# ('a', 'b', 'c')
# <class 'tuple'>

# %%
a=[34,45,56,6,6,3]
print(a[3])     # Indexing
# Out:
# 6

# %%
a=(32,34,3,43,4,3,43,4,3,3,4,)
print(a[0:5])          # slicing a list
print(a[::2])
# Out:
# (32, 34, 3, 43, 4)
# (32, 3, 4, 43, 3, 4)

# %%
a=(1,2,3,4,5,6,7,8,)
print(a[::-1])
print(a[::])
print(a[3:])
print(a[:4])        # multiple slicing method
print(a[-2:-5])
# Out:
# (8, 7, 6, 5, 4, 3, 2, 1)
# (1, 2, 3, 4, 5, 6, 7, 8)
# (4, 5, 6, 7, 8)
# (1, 2, 3, 4)
# ()

# %%
a=(1,2,3,4,5,6,7,8,)
y=list(a)
y.append(9)
a=tuple(y)          # we have to add the element so we first convert tuple into list then made changes then we change the list into tuple
print(a)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
this_tuple=("a","b","c")
for i in this_tuple:
    print(i)          # using loop for the tuple
# Out:
# a
# b
# c

# %%
a=("a","b","c")
b=(1,2,3)
c=a+b
print(c)          # Join two tuple
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
a=["apple","banana","cherry"]
b=a*3
print(b)          # multiply tuple
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'banana', 'cherry', 'apple', 'banana', 'cherry']

# %%
T=(1,2,3,4,5,6)
print(T*2)
print(T+T+T)
print(len(T))
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)
# 6

# %%
# write a prgormm to take 5 input from the user and store it in a
T=()
i=0
while i<5:
    num=int(input("Enter the values please"))
